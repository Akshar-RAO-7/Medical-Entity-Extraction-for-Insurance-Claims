# %% [markdown]
# # Design a system to identify and extract entities like patient demographics, diseases, and treatment details from conversation transcripts to streamline medical insurance claim processing.

# %%
# !pip install wordcloud
# !pip install textblob
# Out:
# Requirement already satisfied: wordcloud in .\.venv\Lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in .\.venv\Lib\site-packages (from wordcloud) (2.4.6)
# Requirement already satisfied: pillow in .\.venv\Lib\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (from wordcloud) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (26.2)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: textblob in .\.venv\Lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in .\.venv\Lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in .\.venv\Lib\site-packages (from nltk>=3.9->textblob) (8.4.1)
# Requirement already satisfied: joblib in .\.venv\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\.venv\Lib\site-packages (from nltk>=3.9->textblob) (2026.5.9)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from wordcloud import WordCloud
from textblob import TextBlob
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# Load the conversation transcripts into a DataFrame
df = pd.read_csv("Doctor patient conversation .csv")

# %%
df.head(3000)
# Out:
#                                                    data  \
# 0     This 60-year-old male was hospitalized due to ...
# 1     A 39-year-old man was hospitalized due to an i...
# 2     One week after a positive COVID-19 result this...
# 3     This 69-year-old male was admitted to the ICU ...
# 4     This 57-year-old male was admitted to the ICU ...
# ...                                                 ...
# 2995  A 43-year-old female with dyspnoea was transfe...
# 2996  A 63-year-old female presented in 2016 with pa...
# 2997  A 72 year old female, with no significant past...
# 2998  A 32-year-old female at pregnancy week 22 was ...
# 2999  We report a case of a 40-year-old female (grav...
#
#                                            conversation
# 0     Doctor: Good morning, how are you feeling toda...
# 1     Doctor: Hello, how are you feeling today?\nPat...
# 2     Doctor: Hello, how are you feeling today?\nPat...
# 3     Doctor: Hello, how are you feeling today?\nPat...
# 4     Doctor: Good morning, how are you feeling toda...
# ...                                                 ...
# 2995  Doctor: Good afternoon. You were transferred t...
# 2996  Doctor: Hello, how are you feeling today?\nPat...
# 2997  Doctor: Good morning, how are you feeling toda...
# 2998  Doctor: Hello, how are you feeling today?\nPat...
# 2999  Doctor: Hello, how can I help you today?\nPati...
#
# [3000 rows x 2 columns]

# %% [markdown]
# # **Exploratory Data Analysis(EDA)**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3377 entries, 0 to 3376
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data          3375 non-null   str
#  1   conversation  3375 non-null   str
# dtypes: str(2)
# memory usage: 52.9 KB

# %%
df.describe()
# Out:
#                                                      data  \
# count                                                3375
# unique                                               3375
# top     This 60-year-old male was hospitalized due to ...
# freq                                                    1
#
#                                              conversation
# count                                                3375
# unique                                               3375
# top     Doctor: Good morning, how are you feeling toda...
# freq                                                    1

# %%
# Check for missing values
df.isnull().sum()
# Out:
# data            2
# conversation    2
# dtype: int64

# %%
df.columns
# Out:
# Index(['data', 'conversation'], dtype='str')

# %%
# Handle missing values and ensure all entries are strings
df['conversation'] = df['conversation'].fillna("").astype(str)

# Calculate text length
df['text_length'] = df['conversation'].apply(len)

# Plot
plt.figure(figsize=(10, 6))
sns.histplot(df['text_length'], bins=50, kde=True)
plt.title('Distribution of Conversation Lengths')
plt.xlabel('Length of Conversation')
plt.ylabel('Frequency')
plt.show()

# %%
#Exploring Common Themes in Conversations Using a Word Cloud
nltk.download('stopwords')

text = ' '.join(df['conversation'].dropna())
wordcloud = WordCloud(background_color="black").generate(text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear") #displays the word cloud as an image.
plt.title('Word Cloud for Conversation')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Akshayarao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **NLP** **Preprocessing**

# %%
import nltk

# Download 'punkt_tab' data package
nltk.download('punkt_tab')
nltk.download('wordnet') # Download the 'wordnet' dataset

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# ... (rest of your imports and setup)

# Assign stopwords to a variable called stop_words
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer() # also initialize lemmatizer here

def preprocess_text(text):
    # 1. Convert to lowercase (handle float values)
    if isinstance(text, float):
        text = str(text)  # Convert float to string
    text = text.lower()

    #2.Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    #3.Tokenize text
    tokens = word_tokenize(text)

    #4.Remove stopwords and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]

    #5.Join tokens back into a single string
    return ' '.join(tokens)

df['processed_text'] = df['conversation'].apply(preprocess_text)
print(df[['conversation', 'processed_text']].head())
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Akshayarao\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Akshayarao\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                         conversation  \
# 0  Doctor: Good morning, how are you feeling toda...
# 1  Doctor: Hello, how are you feeling today?\nPat...
# 2  Doctor: Hello, how are you feeling today?\nPat...
# 3  Doctor: Hello, how are you feeling today?\nPat...
# 4  Doctor: Good morning, how are you feeling toda...
#
#                                       processed_text
# 0  doctor good morning feeling today patient im f...
# 1  doctor hello feeling today patient great ive h...
# 2  doctor hello feeling today patient great ive t...
# 3  doctor hello feeling today patient good doctor...
# 4  doctor good morning feeling today patient good...

# %% [markdown]
# # **Sentiment Analysis**

# %%
#Using TextBlob
# Function to get sentiment polarity
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# Apply sentiment analysis to the processed_text column
df['sentiment'] = df['processed_text'].apply(get_sentiment)

# Display the sentiment scores
print(df[['processed_text', 'sentiment']].head())

# Plot
plt.figure(figsize=(10, 6))
sns.histplot(df['sentiment'], bins=50, kde=True)
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()
# Out:
#                                       processed_text  sentiment
# 0  doctor good morning feeling today patient im f...   0.198718
# 1  doctor hello feeling today patient great ive h...   0.123464
# 2  doctor hello feeling today patient great ive t...   0.203988
# 3  doctor hello feeling today patient good doctor...  -0.077257
# 4  doctor good morning feeling today patient good...   0.185763

# %% [markdown]
# # RoBERTa

# %%
# !pip install transformers torch spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting transformers
#   Downloading transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# Collecting torch
#   Downloading torch-2.13.0-cp314-cp314-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: spacy in .\.venv\Lib\site-packages (3.8.13)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.26.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.17 in .\.venv\Lib\site-packages (from transformers) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from transformers) (26.2)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: regex>=2025.10.22 in .\.venv\Lib\site-packages (from transformers) (2026.5.9)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in .\.venv\Lib\site-packages (from transformers) (0.26.2)
# Collecting safetensors>=0.8.0 (from transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.60 in .\.venv\Lib\site-packages (from transformers) (4.67.3)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading filelock-3.32.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading fsspec-2026.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.5.2-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.16)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in .\.venv\Lib\site-packages (from torch) (82.0.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in .\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in .\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in .\.venv\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in .\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in .\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in .\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in .\.venv\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in .\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in .\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in .\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in .\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\.venv\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in .\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in .\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: wrapt in .\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading transformers-5.14.1-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 4.5 MB/s eta 0:00:02
#    -------- ------------------------------- 1.3/6.3 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 2.4/6.3 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.3 MB 3.7 MB/s eta 0:00:01
#    --------------------- ------------------ 3.4/6.3 MB 3.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.3 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.3 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 3.1 MB/s  0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 3.2 MB/s  0:00:00
# Installing collected packages: mpmath, sympy, safetensors, pyyaml, networkx, hf-xet, fsspec, filelock, click, torch, huggingface-hub, tokenizers, transformers
#
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
#    --- ------------------------------------  1/13 [sympy]
# ...
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
#    --------------------------- ------------  9/13 [torch]
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# ERROR: Could not install packages due to an OSError: [WinError 206] The filename or extension is too long: 'c:\\Users\\Akshayarao\\OneDrive\\Desktop\\AKSHAR PROJECTS\\Medical-Entity-Extraction-for-Insurance-Claims-main\\.venv\\Lib\\site-packages\\torch-2.13.0.dist-info\\licenses\\third_party\\kineto\\libkineto\\third_party\\dynolog\\third_party\\DCGM\\testing\\python3\\libs_3rdparty'
#
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 1.6 MB/s eta 0:00:08
#      --- ------------------------------------ 1.0/12.8 MB 1.7 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.6/12.8 MB 1.9 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.9 MB/s eta 0:00:06
#      -------- ------------------------------- 2.6/12.8 MB 2.1 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.4/12.8 MB 2.3 MB/s eta 0:00:05
#      ------------- -------------------------- 4.2/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.9 MB/s eta 0:00:03
#      -------------------- ------------------- 6.6/12.8 MB 3.2 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 3.5 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 3.7 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 4.2 MB/s  0:00:03
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import spacy
from transformers import pipeline

nlp = spacy.load("en_core_web_sm")

roberta_ner_pipeline = pipeline(
    "ner", 
    model="recasens/roberta-base-health-ner", 
    aggregation_strategy="simple"
)


def extract_entities_with_roberta(raw_text):
    
    if not isinstance(raw_text, str) or raw_text.strip() == "":
        return {"patient_name": None, "patient_age": None, "disease": None, "treatment": None, "date": None}
    
    claim = {
        "patient_name": None,
        "patient_age": None,
        "disease": [],
        "treatment": [],
        "date": None,
    }
    
    
    spacy_doc = nlp(raw_text)
    for ent in spacy_doc.ents:
        if ent.label_ == "PERSON" and not claim["patient_name"]:
            claim["patient_name"] = ent.text
        elif ent.label_ == "DATE" and not claim["date"]:
            claim["date"] = ent.text
        elif ent.label_ == "CARDINAL" and "old" in ent.sent.text.lower() and not claim["patient_age"]:
            claim["patient_age"] = ent.text

    
    try:
        roberta_results = roberta_ner_pipeline(raw_text)
        for entity in roberta_results:
            # Match RoBERTa's specific medical tags
            if entity['entity_group'] in ['DISEASE', 'CONDITION', 'SINDROME']:
                claim["disease"].append(entity['word'])
            elif entity['entity_group'] in ['TREATMENT', 'MEDICATION', 'PROCEDURE']:
                claim["treatment"].append(entity['word'])
    except Exception as e:
        print(f"Error processing row with RoBERTa: {e}")

    # Clean up entity lists by removing duplicates and joining into strings
    claim["disease"] = ", ".join(list(set(claim["disease"]))) if claim["disease"] else None
    claim["treatment"] = ", ".join(list(set(claim["treatment"]))) if claim["treatment"] else None
    
    return claim


def validate_claim(claim):
    required_fields = ["patient_name", "disease", "treatment", "date"]
    missing_fields = [field for field in required_fields if not claim[field]]
    return len(missing_fields) == 0, missing_fields






df['claim'] = df['conversation'].apply(extract_entities_with_roberta)
df['is_valid'], df['missing_fields'] = zip(*df['claim'].apply(validate_claim))print("Extracting claims using RoBERTa architecture...")




print("Extracting claims using RoBERTa architecture...")
df['claim'] = df['conversation'].apply(extract_entities_with_roberta)
df['is_valid'], df['missing_fields'] = zip(*df['claim'].apply(validate_claim))
df['claim'] = df['conversation'].apply(extract_entities_with_roberta)

df['is_valid'], df['missing_fields'] = zip(*df['claim'].apply(validate_claim))
# Out:
#   Cell In[15], line 66
#     df['is_valid'], df['missing_fields'] = zip(*df['claim'].apply(validate_claim))df['claim'] = df['conversation'].apply(extract_entities_with_roberta)print("Extracting claims using RoBERTa architecture...")print("Extracting claims using RoBERTa architecture...")
#                                                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Medical Insurance Claim Processing

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in .\.venv\Lib\site-packages (3.8.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in .\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in .\.venv\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in .\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in .\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in .\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in .\.venv\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in .\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in .\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in .\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in .\.venv\Lib\site-packages (from spacy) (0.26.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in .\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in .\.venv\Lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in .\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in .\.venv\Lib\site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in .\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in .\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in .\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in .\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in .\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/12.8 MB 2.2 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/12.8 MB 1.6 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.6 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.6 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.7 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.7 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 1.7 MB/s eta 0:00:06
#      ------------ --------------------------- 3.9/12.8 MB 1.7 MB/s eta 0:00:06
#      ------------- -------------------------- 4.5/12.8 MB 1.8 MB/s eta 0:00:05
#      -------------- ------------------------- 4.7/12.8 MB 1.8 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.2/12.8 MB 1.8 MB/s eta 0:00:05
#      ------------------ --------------------- 5.8/12.8 MB 1.9 MB/s eta 0:00:04
#      ------------------ --------------------- 6.0/12.8 MB 1.9 MB/s eta 0:00:04
#      -------------------- ------------------- 6.6/12.8 MB 1.9 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.1/12.8 MB 1.9 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.6/12.8 MB 1.9 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 2.0 MB/s eta 0:00:03
#      --------------------------- ------------ 8.7/12.8 MB 2.0 MB/s eta 0:00:03
#      ---------------------------- ----------- 9.2/12.8 MB 2.0 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 2.0 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 2.0 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 2.0 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 2.0 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.0 MB/s  0:00:06
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Function to extract entities
def extract_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Apply entity extraction to the 'processed_text' column
df['entities'] = df['processed_text'].apply(extract_entities)
# Medical Insurance Claim Processing

def process_insurance_claim(entities):
    claim = {
        "patient_name": None,
        "patient_age": None,
        "disease": None,
        "treatment": None,
        "date": None,
    }

    for entity, label in entities:
        if label == "PERSON":
            claim["patient_name"] = entity
        elif label == "DATE":
            claim["date"] = entity
        elif label == "GPE":
            claim["location"] = entity
        elif label == "NORP":
            claim["nationality"] = entity
        elif label == "DISEASE":
            claim["disease"] = entity
        elif label == "TREATMENT":
            claim["treatment"] = entity

    return claim

# Apply claim processing to each conversation
df['claim'] = df['entities'].apply(process_insurance_claim)

# Display the processed claims
print(df[['processed_text', 'claim']].head())

# Validate Claims
def validate_claim(claim):
    required_fields = ["patient_name", "disease", "treatment", "date"]
    missing_fields = [field for field in required_fields if not claim[field]]
    return len(missing_fields) == 0, missing_fields

# Apply validation to each claim
df['is_valid'], df['missing_fields'] = zip(*df['claim'].apply(validate_claim))

# Display the processed claims
print(df[['processed_text', 'claim']].head())

# Generate Claim Output
valid_claims = df[df['is_valid']]['claim']

import json
valid_claims_json = valid_claims.to_json(orient="records", indent=4)
print("Valid Claims in JSON Format:")
print(valid_claims_json)

with open("valid_claims.json", "w") as f:
    f.write(valid_claims_json)

# PLOT
plt.figure(figsize=(8, 5))
sns.countplot(x=df['is_valid'])
plt.title('Claim Validation Results')
plt.xlabel('Is Valid Claim?')
plt.ylabel('Number of Claims')
plt.show()
# Out:
#                                       processed_text  \
# 0  doctor good morning feeling today patient im f...
# 1  doctor hello feeling today patient great ive h...
# 2  doctor hello feeling today patient great ive t...
# 3  doctor hello feeling today patient good doctor...
# 4  doctor good morning feeling today patient good...
#
#                                                claim
# 0  {'patient_name': None, 'patient_age': None, 'd...
# 1  {'patient_name': None, 'patient_age': None, 'd...
# 2  {'patient_name': None, 'patient_age': None, 'd...
# 3  {'patient_name': None, 'patient_age': None, 'd...
# 4  {'patient_name': None, 'patient_age': None, 'd...
#                                       processed_text  \
# 0  doctor good morning feeling today patient im f...
# 1  doctor hello feeling today patient great ive h...
# 2  doctor hello feeling today patient great ive t...
# 3  doctor hello feeling today patient good doctor...
# 4  doctor good morning feeling today patient good...
#
#                                                claim
# 0  {'patient_name': None, 'patient_age': None, 'd...
# 1  {'patient_name': None, 'patient_age': None, 'd...
# 2  {'patient_name': None, 'patient_age': None, 'd...
# 3  {'patient_name': None, 'patient_age': None, 'd...
# 4  {'patient_name': None, 'patient_age': None, 'd...
# Valid Claims in JSON Format:
# [
#
# ]

# %%
#PLOT
valid_claim_count = df['is_valid'].value_counts()

plt.figure(figsize=(8, 5))
plt.pie(valid_claim_count, labels=valid_claim_count.index, autopct='%1.1f%%', startangle=90, colors=['#4CAF50', '#FF5733'])
plt.title('Claim Validation Results (Valid vs Invalid)')
plt.axis('equal')
plt.show()
